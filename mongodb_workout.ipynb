# %%
from pymongo import MongoClient
import pymongoarrow.monkey

# %%
pymongoarrow.monkey.patch_all()

# %%
from pymongo.client_session import ClientSession

# %%
help(ClientSession)
# Out:
# Help on class ClientSession in module pymongo.client_session:
#
# class ClientSession(builtins.object)
#  |  ClientSession(client, server_session, options, authset, implicit)
#  |
#  |  A session for ordering sequential operations.
#  |
#  |  :class:`ClientSession` instances are **not thread-safe or fork-safe**.
#  |  They can only be used by one thread or process at a time. A single
#  |  :class:`ClientSession` cannot be used to run multiple operations
#  |  concurrently.
#  |
#  |  Should not be initialized directly by application developers - to create a
#  |  :class:`ClientSession`, call
#  |  :meth:`~pymongo.mongo_client.MongoClient.start_session`.
#  |
#  |  Methods defined here:
#  |
#  |  __enter__(self)
#  |
#  |  __exit__(self, exc_type, exc_val, exc_tb)
#  |
#  |  __init__(self, client, server_session, options, authset, implicit)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  abort_transaction(self)
# ...

# %%
data = {
  "property": [
    "Aparthotel",
    "Apartment",
    "Barn"
  ],
  "rooms": [
    "Entire home/apt"
  ],
  "room_num": "1",
  "bed_num": "1",
  "bath_room_num": "Any",
  "essential_amenities": [
    "Kitchen",
    "Washing machine"
  ],
  "features_amenities": [
    "Free parking",
    "Gym"
  ],
  "location_amenities": [],
  "safety_amenities": [],
  "price_range": [
    100,
    1000
  ]
}

# %%
help(MongoClient)
# Out:
# Help on class MongoClient in module pymongo.mongo_client:
#
# class MongoClient(pymongo.common.BaseObject)
#  |  MongoClient(host=None, port=None, document_class=<class 'dict'>, tz_aware=None, connect=None, type_registry=None, **kwargs)
#  |
#  |  A client-side representation of a MongoDB cluster.
#  |
#  |  Instances can represent either a standalone MongoDB server, a replica
#  |  set, or a sharded cluster. Instances of this class are responsible for
#  |  maintaining up-to-date state of the cluster, and possibly cache
#  |  resources related to this, including background threads for monitoring,
#  |  and connection pools.
#  |
#  |  Method resolution order:
#  |      MongoClient
#  |      pymongo.common.BaseObject
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __enter__(self)
#  |
#  |  __eq__(self, other)
#  |      Return self==value.
#  |
#  |  __exit__(self, exc_type, exc_val, exc_tb)
#  |
#  |  __getattr__(self, name)
#  |      Get a database by name.
# ...

# %%
# uri = "mongodb+srv://navaneethan:yH6rGViy5BRvDwIe@airbnb-analysis.yiorqff.mongodb.net/?retryWrites=true&w=majority&appName=Airbnb-Analysis"
uri = "mongodb+srv://navaneethan:BgH6Qn03wRtmdGoR@airbnb-analysis.yiorqff.mongodb.net/?retryWrites=true&w=majority&appName=Airbnb-Analysis"

# %%
client_mongodb = MongoClient(uri)

# %%
client_mongodb.admin.command('ping')
# Out:
# {'ok': 1}

# %%
get_db = client_mongodb.get_database(name="airbnb_analysis")
list(get_db["airbnb_main_data"].find({"_id": "1003530"}))
# get_db = client_mongodb["airbnb_analysis"]
# Out:
# [{'_id': '1003530',
#   'listing_url': 'https://www.airbnb.com/rooms/1003530',
#   'name': 'New York City - Upper West Side Apt',
#   'summary': '',
#   'space': 'Murphy bed, optional second bedroom available. Wifi available, Hulu, Netflix, TV Eat-in kitchen. Bathroom with great shower/bath.  Washer/dryer in basement.',
# ...

# %%
get_db["airbnb_main_data"].find_pandas_all({"$and": [{"property_type": {"$in": data["property"]}}, {"room_type": {'$in': data["rooms"]}}]})
# Out:
#            _id                            listing_url  \
# 0      1003530   https://www.airbnb.com/rooms/1003530
# 1     10059872  https://www.airbnb.com/rooms/10059872
# 2     10091713  https://www.airbnb.com/rooms/10091713
# 3     10096773  https://www.airbnb.com/rooms/10096773
# 4     10140368  https://www.airbnb.com/rooms/10140368
# ...        ...                                    ...
# 3605   9936016   https://www.airbnb.com/rooms/9936016
# 3606   9951865   https://www.airbnb.com/rooms/9951865
# 3607   9907907   https://www.airbnb.com/rooms/9907907
# 3608   9983221   https://www.airbnb.com/rooms/9983221
# 3609   9917859   https://www.airbnb.com/rooms/9917859
#
#                                                   name  \
# 0                  New York City - Upper West Side Apt
# 1                   Soho Cozy, Spacious and Convenient
# 2     Surry Hills Studio - Your Perfect Base in Sydney
# 3                            Easy 1 Bedroom in Chelsea
# ...

# %%
from pymongoarrow.api import Schema

# %%
from typing import Optional
schemas = Schema({
    'price': int,
    'minimum_nights': str,
    'maximum_nights': str,
    "minimum night prices": int,
    "maximum night prices": int,
    "thumbnail_url": str,
    "_id": str,
    "name_country": str,
    "review": int,
    "essentail": bool
})

# %%
db_conditon = {'$and': [{'property_type': {'$in': ['Aparthotel']}}, 
                        # {'room_type': {'$in': ['Entire home/apt']}}, 
                        # {'bedrooms': '2'}, {'beds': '2'}, 
                        # {'$or': [{"amenities": "essentail"}]}, 
                        # {
    # 'minimum_night_price': {'$gte': 1147}}, {'maximum_night_price': {'$lte': 3577}}
    ]}

# %%
get_db["airbnb_main_data"].aggregate_pandas_all([
        {"$addFields": {
            "minimum night prices": {"$multiply": [{"$toInt": "$price"}, {"$toInt": "$minimum_nights"}]}, 
                        "maximum night prices": {"$multiply": [{"$toInt": "$price"}, {"$toInt": "$maximum_nights"}]},
                        "thumbnail_url": "$images.picture_url", "name_country": {"$concat": ["$name", ",", "$address.country"]},
                        "review_rating": "$review_scores.review_scores_rating", "essentail" :{ '$setDifference': ['$amenities', "$amenities"]}
                        }
         },
        {"$match": db_conditon},
        # {"$project": {"price" : 1, "minimum_nights": 1, "maximum_nights": 1, "minimum night prices": 1, "maximum night prices": 1, "essentail": 1, "amenities": 1}}
        # {"$project": {"thumbnail_url": "$images.picture_url"}}
])
# Out:
#          _id                            listing_url  \
# 0   13846473  https://www.airbnb.com/rooms/13846473
# 1   14405901  https://www.airbnb.com/rooms/14405901
# 2    1588234   https://www.airbnb.com/rooms/1588234
# 3    2418216   https://www.airbnb.com/rooms/2418216
# 4   25248977  https://www.airbnb.com/rooms/25248977
# 5   21842463  https://www.airbnb.com/rooms/21842463
# 6   21929645  https://www.airbnb.com/rooms/21929645
# 7     424137    https://www.airbnb.com/rooms/424137
# 8    4740503   https://www.airbnb.com/rooms/4740503
# 9    6242962   https://www.airbnb.com/rooms/6242962
# 10  28211805  https://www.airbnb.com/rooms/28211805
# 11  29697871  https://www.airbnb.com/rooms/29697871
# 12  29432887  https://www.airbnb.com/rooms/29432887
# 13  29032115  https://www.airbnb.com/rooms/29032115
# 14  28714609  https://www.airbnb.com/rooms/28714609
# 15  29870769  https://www.airbnb.com/rooms/29870769
# 16  29872103  https://www.airbnb.com/rooms/29872103
# ...

# %%
get_db["airbnb_main_data"].aggregate_pandas_all([
        {"$addFields": {
            "minimum night prices": {"$multiply": [{"$toInt": "$price"}, {"$toInt": "$minimum_nights"}]}, 
                        "maximum night prices": {"$multiply": [{"$toInt": "$price"}, {"$toInt": "$maximum_nights"}]},
                        "thumbnail_url": "$images.picture_url", "name_country": {"$concat": ["$name", ",", "$address.country"]},
                        "review_rating": "$review_scores.review_scores_rating", "essential": {'$setDifference': ['$amenities', ['Kitchen', 'Washing machine']]}}
         },
        {"$match": {"$and": [{"property_type": {"$in": data["property"]}}, {"room_type": {'$in': data["rooms"]}}, {"minimum night prices": {"$gte":data["price_range"][0]}}, 
                             {"maximum night prices": {"$lte":data["price_range"][1]}} ]}},
        {"$project": {"price" : 1, "minimum_nights": 1, "maximum_nights": 1, "minimum night prices": 1, "maximum night prices": 1, "essential": 1}}
        # {"$project": {"thumbnail_url": "$images.picture_url"}}
])
# Out:
#          _id minimum_nights maximum_nights  price  minimum night prices  \
# 0    1022200              7              7  135.0                   945
# 1   11567815              2              3   90.0                   180
# 2   11848397              1              3  165.0                   165
# 3   11841749              2              2   79.0                   158
# 4   12137640              5             21   30.0                   150
# 5   13748617              2              8   60.0                   120
# 6   16158314              3              5  200.0                   600
# 7   16869922              4              4   85.0                   340
# 8   16971327              2              6   79.0                   158
# 9   16976284              2              7   60.0                   120
# 10  17463241              1              6  110.0                   110
# 11   1731242              4              8  100.0                   400
# ...

# %%
get_db["airbnb_main_data"].find_one()
# Out:
# {'_id': '1003530',
#  'listing_url': 'https://www.airbnb.com/rooms/1003530',
#  'name': 'New York City - Upper West Side Apt',
#  'summary': '',
#  'space': 'Murphy bed, optional second bedroom available. Wifi available, Hulu, Netflix, TV Eat-in kitchen. Bathroom with great shower/bath.  Washer/dryer in basement.',
# ...

# %%
for i in get_db["airbnb_main_data"].find({"$and": [{"property_type": {"$in": data["property"]}}, {"room_type": {'$in': data["rooms"]}}]}):
    print(i)
    break
# Out:
# {'_id': '1003530', 'listing_url': 'https://www.airbnb.com/rooms/1003530', 'name': 'New York City - Upper West Side Apt', 'summary': '', 'space': 'Murphy bed, optional second bedroom available. Wifi available, Hulu, Netflix, TV Eat-in kitchen. Bathroom with great shower/bath.  Washer/dryer in basement.', 'description': "Murphy bed, optional second bedroom available. Wifi available, Hulu, Netflix, TV Eat-in kitchen. Bathroom with great shower/bath.  Washer/dryer in basement. New York City! Great neighborhood - many terrific restaurants, bakeries, bagelries. Within easy walking distance are restaurants with the cuisines from India, Thailand, Japan, China, Mexico, South America and Europe.  As well as the many small independent stores that line Broadway, there chain stores such as Urban Outfitters (clothing), Whole Foods (groceries), Sephora (cosmetics), Michaels (crafts), and Modell's (sporting goods). Equidistant to Central Park and Riverside Park which have walking/running/biking trai
# ...

# %%
list(get_db["airbnb_main_data"].find({"beds": 1}))

# %%
get_db["airbnb_main_data"].find({"rooms": {'$in': data["rooms"]}})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 get_db["airbnb_main_data"].find({"rooms": {'$in': data["rooms"]}})
#
# NameError: name 'data' is not defined

# %%
get_collection.find_one()
# Out:
# {'_id': '1003530',
#  'listing_url': 'https://www.airbnb.com/rooms/1003530',
#  'name': 'New York City - Upper West Side Apt',
#  'summary': '',
#  'space': 'Murphy bed, optional second bedroom available. Wifi available, Hulu, Netflix, TV Eat-in kitchen. Bathroom with great shower/bath.  Washer/dryer in basement.',
# ...

# %%
dir(get_collection.find({"property_type": data["property"][0]}))
# Out:
# ['_Cursor__address',
#  '_Cursor__allow_disk_use',
#  '_Cursor__batch_size',
#  '_Cursor__check_okay_to_chain',
#  '_Cursor__codec_options',
#  '_Cursor__collation',
#  '_Cursor__collection',
#  '_Cursor__collname',
#  '_Cursor__comment',
#  '_Cursor__data',
#  '_Cursor__dbname',
#  '_Cursor__die',
#  '_Cursor__empty',
#  '_Cursor__exhaust',
#  '_Cursor__exhaust_mgr',
#  '_Cursor__explain',
#  '_Cursor__explicit_session',
#  '_Cursor__hint',
#  '_Cursor__id',
#  '_Cursor__killed',
#  '_Cursor__limit',
#  '_Cursor__manipulate',
#  '_Cursor__max',
#  '_Cursor__max_await_time_ms',
#  '_Cursor__max_scan',
#  '_Cursor__max_time_ms',
#  '_Cursor__min',
#  '_Cursor__modifiers',
#  '_Cursor__ordering',
#  '_Cursor__projection',
#  '_Cursor__query_flags',
#  '_Cursor__query_spec',
#  '_Cursor__read_concern',
#  '_Cursor__read_preference',
#  '_Cursor__retrieved',
#  '_Cursor__return_key',
#  '_Cursor__send_message',
#  '_Cursor__session',
#  '_Cursor__set_hint',
#  '_Cursor__show_record_id',
# ...

# %%
get_collection.find({"property_type": data["property"][0]}).limit(1)

# %%
print(get_db["airbnb_main_data"].aggregate_pandas_all([
        # {"$addFields": {
        #     "minimum night prices": {"$multiply": [{"$toInt": "$price"}, {"$toInt": "$minimum_nights"}]}, 
        #                 "maximum night prices": {"$multiply": [{"$toInt": "$price"}, {"$toInt": "$maximum_nights"}]},
        #                 "thumbnail_url": "$images.picture_url", "name_country": {"$concat": ["$name", ",", "$address.country"]}},
                        # "review_rating": "$review_scores.review_scores_rating"}
        #  },
        {"$match": {"$and": [{"property_type": {"$in": data["property"]}}, {"room_type": {'$in': data["rooms"]}}, {"minimum night prices": {"$gte":data["price_range"][0]}}, 
                             {"maximum night prices": {"$lte":data["price_range"][1]}} ]}},
        # {"$group": {"_id": "$property_id"}},
        # {"$project": {"price" : 1, "minimum_nights": 1, "maximum_nights": 1, "minimum night prices": 1, "maximum night prices": 1, "essential": 1}}
        # {"$project": {"thumbnail_url": "$images.picture_url"}}
]))
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
data = {
  "property": [
    "Aparthotel",
    "Apartment",
    "Barn",
    "Bed and breakFast",
    "Boat",
    "Boutique hotel",
    "Bungalow",
    "Cabin",
    "Camper/RV",
    "Campsite",
    "Casa particular (Cuba)",
    "Castle",
    "Chalet",
    "Condominium",
    "Cattage"
  ],
  "rooms": [
    "Entire home/apt",
    "Private room"
  ],
  "room_num": "Any",
  "bed_num": "Any",
  "bath_room_num": "Any",
  "essential_amenities": [
    "Wifi",
    "Kitchen",
    "Washing machine",
    "Heating"
  ],
  "features_amenities": [],
  "location_amenities": [],
  "safety_amenities": [],
  "price_range": [
    1543,
    5341
  ]
}

# %%
db_conditon = {'$and': [{'property_type': {'$in': ['Aparthotel', 'Apartment', 'Barn', 'Bed and breakFast', 'Boat', 'Boutique hotel', 'Bungalow', 'Cabin', 'Camper/RV', 'Campsite', 'Casa particular (Cuba)', 'Castle', 'Chalet', 'Condominium', 'Cattage']}}, {'room_type': {'$in': ['Entire home/apt', 'Private room']}}, {'$or': [{'amenities': {'$in': ['Wifi']}}, {'amenities': {'$in': ['Kitchen']}}, {'amenities': {'$in': ['Washing machine']}}, {'amenities': {'$in': ['Heating']}}]}, {'minimum_night_price': {'$gte': 1543}}, {'maximum_night_price': {'$lte': 5341}}]}

# %%
resut = get_db["airbnb_main_data"].aggregate_pandas_all([
    # {"$group": {"_id": "$property_type", "avg_price": {"$max": "$price"}}},
    {"$match": db_conditon}
])

# %%
print(resut)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
